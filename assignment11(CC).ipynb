# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrutithakur30/UCS420/blob/main/assignment11(CC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ques 1. Design a Cognitive Assistant for Reading Labels of medicine bottle

# %% [markdown]
# ![Screenshot 2025-05-03 234838.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-05-03 234805.png](data:image/png;base64,...)

# %% [markdown]
# # Ques 2.Design an Emotion-aware Cognitive Assistant using Facial Expression Detection

# %% [markdown]
# ![x.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![y.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![z.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2025-05-04 at 00.11.37_f20c6c4e.jpg](data:image/jpeg;base64,...)
